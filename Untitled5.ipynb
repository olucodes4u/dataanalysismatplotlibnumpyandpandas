# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([0,4,5,7,9,11])
y=np.array([2,3,5,0,7,9])
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0,
              np.pi/6,
              np.pi/4,
              np.pi/3,
              np.pi/2,
              2*np.pi/3,
              3*np.pi/4,
              5*np.pi/6,
              np.pi,
              7*np.pi/6,
              5*np.pi/4,
              4*np.pi/3,
              3*np.pi/2,
              5*np.pi/3,
              7*np.pi/4,
              11*np.pi/6,
              2*np.pi
             ])

y = np.array([0.0,
              0.5,
              0.707,
              0.866,
              1.0,
              0.866,
              0.707,
              0.5,
              0.0,
              -0.5,
              -0.707,
              -0.866,
              -1.0,
              -0.866,
              -0.707,
              -0.5,
              0.0
             ])

plt.plot(x, y)
plt.show()
